# %% [markdown]
# # Understanding Pandas Series and DataFrames - Lab
#
# ## Introduction
#
# In this lab, let's get some hands on practice working with data cleanup using Pandas.
#
# ## Objectives
# You will be able to:
#
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes
#
# ## Let's get started!

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('turnstile_180901.txt')
print(len(df))
df.head()
# Out:
# 197625
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# ## Rename all the columns to lower case

# %%
#Your code here
new_cols = [col.lower() for col in df.columns]
df.columns = new_cols
df.head()
# Out:
#     c/a  unit       scp station linename division        date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# ## Change the Index to be the Line Names

# %%
#Your code here
df = df.set_index('entries')
df.head()
# Out:
#          index linename   c/a  unit       scp station division        date  \
# entries
# 6736067      0  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018
# 6736087      1  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018
# 6736105      2  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018
# 6736180      3  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018
# 6736349      4  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018
#
#              time     desc  \
# entries
# 6736067  00:00:00  REGULAR
# 6736087  04:00:00  REGULAR
# 6736105  08:00:00  REGULAR
# 6736180  12:00:00  REGULAR
# 6736349  16:00:00  REGULAR
#
#          exits
# entries
# 6736067                                            2283184
# 6736087                                            2283188
# 6736105                                            2283229
# 6736180                                            2283314
# 6736349                                            2283384

# %% [markdown]
# ## Painstakingly change the index back

# %%
# Your code here
df = df.reset_index()
df.head()
# Out:
#    entries  index linename   c/a  unit       scp station division        date  \
# 0  6736067      0  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018
# 1  6736087      1  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018
# 2  6736105      2  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018
# 3  6736180      3  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018
# 4  6736349      4  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018
#
#        time     desc  \
# 0  00:00:00  REGULAR
# 1  04:00:00  REGULAR
# 2  08:00:00  REGULAR
# 3  12:00:00  REGULAR
# 4  16:00:00  REGULAR
#
#    exits
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# ## Create another column 'Num_Lines' that is a count of how many lines pass through a station. Then sort your dataframe by this column in descending order

# %%
# Your code here
df['Num_Lines'] = df.linename.map(lambda x: len(x))

# %% [markdown]
# ## Write a function to clean a column name

# %%
def clean(col_name):
    cleaned = col_name.strip()#Your code here; whatever you want to do to col_name. Hint: think back to str methods.
    return cleaned

#This is a list comprehension. It applies your clean function to every item in the list.
#We then reassign that to df.columns
#You shouldn't have to change anything here.
#Your function above should work appropriately here.
df.columns = [clean(col) for col in df.columns]

# %%
#This is a list comprehension. It applies your clean function to every item in the list.
#We then reassign that to df.columns
#You shouldn't have to change anything here.
#Your function above should work appropriately here.
df.columns = [clean(col) for col in df.columns]

# %%
#Checking the output, we can see the results.
df.columns
# Out:
# Index(['entries', 'index', 'linename', 'c/a', 'unit', 'scp', 'station',
#        'division', 'date', 'time', 'desc', 'exits', 'Num_Lines'],
#       dtype='object')

# %% [markdown]
# ## Compare subway traffic by day of the week. Display this as a graph.

# %%
#Your code here
df.date = pd.to_datetime(df.date)
df['Dayofweek'] = df.date.dt.dayofweek
grouped = df.groupby('Dayofweek').sum()
grouped.plot(kind='barh')

# %% [markdown]
# ## Is there more subway traffic on a weekend or a weekday?    Be specific in comparing magnitudes

# %%
#Your code here

# %% [markdown]
# ## Drop a couple of columns

# %%
# Your code here
df.drop(["time", "desc", "entries", "linename", "c/a", "station", "Num_Lines"], axis = 1)
# Out:
#          index  unit       scp division       date    exits  Dayofweek
# 0            0  R051  02-00-00      BMT 2018-08-25  2283184          5
# 1            1  R051  02-00-00      BMT 2018-08-25  2283188          5
# 2            2  R051  02-00-00      BMT 2018-08-25  2283229          5
# 3            3  R051  02-00-00      BMT 2018-08-25  2283314          5
# 4            4  R051  02-00-00      BMT 2018-08-25  2283384          5
# 5            5  R051  02-00-00      BMT 2018-08-25  2283425          5
# 6            6  R051  02-00-00      BMT 2018-08-26  2283460          6
# 7            7  R051  02-00-00      BMT 2018-08-26  2283461          6
# 8            8  R051  02-00-00      BMT 2018-08-26  2283483          6
# 9            9  R051  02-00-00      BMT 2018-08-26  2283524          6
# 10          10  R051  02-00-00      BMT 2018-08-26  2283587          6
# 11          11  R051  02-00-00      BMT 2018-08-26  2283631          6
# 12          12  R051  02-00-00      BMT 2018-08-27  2283656          0
# 13          13  R051  02-00-00      BMT 2018-08-27  2283658          0
# 14          14  R051  02-00-00      BMT 2018-08-27  2283736          0
# 15          15  R051  02-00-00      BMT 2018-08-27  2283965          0
# 16          16  R051  02-00-00      BMT 2018-08-27  2284025          0
# 17          17  R051  02-00-00      BMT 2018-08-27  2284091          0
# 18          18  R051  02-00-00      BMT 2018-08-28  2284121          1
# 19          19  R051  02-00-00      BMT 2018-08-28  2284126          1
# 20          20  R051  02-00-00      BMT 2018-08-28  2284216          1
# 21          21  R051  02-00-00      BMT 2018-08-28  2284402          1
# 22          22  R051  02-00-00      BMT 2018-08-28  2284425          1
# 23          23  R051  02-00-00      BMT 2018-08-28  2284478          1
# 24          24  R051  02-00-00      BMT 2018-08-29  2284508          2
# 25          25  R051  02-00-00      BMT 2018-08-29  2284512          2
# 26          26  R051  02-00-00      BMT 2018-08-29  2284600          2
# 27          27  R051  02-00-00      BMT 2018-08-29  2284838          2
# 28          28  R051  02-00-00      BMT 2018-08-29  2284896          2
# 29          29  R051  02-00-00      BMT 2018-08-29  2284941          2
# ...        ...   ...       ...      ...        ...      ...        ...
# 197595  197595  R469  00-05-01      RIT 2018-08-27      348          0
# 197596  197596  R469  00-05-01      RIT 2018-08-27      348          0
# 197597  197597  R469  00-05-01      RIT 2018-08-27      348          0
# 197598  197598  R469  00-05-01      RIT 2018-08-27      348          0
# 197599  197599  R469  00-05-01      RIT 2018-08-27      348          0
# 197600  197600  R469  00-05-01      RIT 2018-08-27      348          0
# 197601  197601  R469  00-05-01      RIT 2018-08-28      348          1
# 197602  197602  R469  00-05-01      RIT 2018-08-28      348          1
# 197603  197603  R469  00-05-01      RIT 2018-08-28      348          1
# 197604  197604  R469  00-05-01      RIT 2018-08-28      348          1
# 197605  197605  R469  00-05-01      RIT 2018-08-28      348          1
# 197606  197606  R469  00-05-01      RIT 2018-08-28      348          1
# 197607  197607  R469  00-05-01      RIT 2018-08-29      348          2
# 197608  197608  R469  00-05-01      RIT 2018-08-29      348          2
# 197609  197609  R469  00-05-01      RIT 2018-08-29      348          2
# 197610  197610  R469  00-05-01      RIT 2018-08-29      348          2
# 197611  197611  R469  00-05-01      RIT 2018-08-29      348          2
# 197612  197612  R469  00-05-01      RIT 2018-08-29      348          2
# 197613  197613  R469  00-05-01      RIT 2018-08-30      348          3
# 197614  197614  R469  00-05-01      RIT 2018-08-30      348          3
# 197615  197615  R469  00-05-01      RIT 2018-08-30      348          3
# 197616  197616  R469  00-05-01      RIT 2018-08-30      348          3
# 197617  197617  R469  00-05-01      RIT 2018-08-30      348          3
# 197618  197618  R469  00-05-01      RIT 2018-08-30      348          3
# 197619  197619  R469  00-05-01      RIT 2018-08-31      348          4
# 197620  197620  R469  00-05-01      RIT 2018-08-31      348          4
# 197621  197621  R469  00-05-01      RIT 2018-08-31      348          4
# 197622  197622  R469  00-05-01      RIT 2018-08-31      348          4
# 197623  197623  R469  00-05-01      RIT 2018-08-31      348          4
# 197624  197624  R469  00-05-01      RIT 2018-08-31      348          4
#
# [197625 rows x 7 columns]

# %% [markdown]
# ## Summary
#
# Great! You practiced your data cleanup-skills using Pandas.
